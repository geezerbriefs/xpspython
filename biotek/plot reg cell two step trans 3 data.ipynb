# %% [markdown]
# # Imports

# %%
#workhorses
import numpy as np
import pandas as pd

import itertools

#for custom colormaps
from matplotlib.colors import LinearSegmentedColormap

#for proxy artists for legends
import matplotlib.lines as mlines

import seaborn as sns

# Plotting modules
import bokeh.io
import bokeh.plotting

bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1008">Loading BokehJS ...</span>
#     </div>

# %%
#plotting things

#%matplotlib qt5 -- I don't know what this is
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

from cycler import cycler


#All of Anandh's customized seaborn/matplotlib settings

sns.set_context("poster", font_scale=1.5, rc={"lines.linewidth": 1.5})
sns.set_style("ticks")
sns.set_style({"xtick.direction": "in","ytick.direction": "in"})

#%config InlineBackend.figure_f.ormats=['svg']

mpl.rc('axes', prop_cycle=(cycler('color', ['k', 'y', 'b','g','y','m','c']) ))

mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42

#mpl.rc('text', usetex=False)
#mpl.rc('text.latex', preamble=r'\usepackage{helvet}
#\renewcommand\familydefault{\sfdefault}\usepackage{sansmath}\sansmath')

    #If you want to use a different font
# mpl.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica'], 
#                  'serif': ['Helvetica']})

tw = 1.5
sns.set_style({"xtick.major.size": 3, "ytick.major.size": 3,
               "xtick.minor.size": 2, "ytick.minor.size": 2,
               'axes.labelsize': 16, 'axes.titlesize': 16,
               'xtick.major.width': tw, 'xtick.minor.width': tw,
               'ytick.major.width': tw, 'ytick.minor.width': tw})

mpl.rc('xtick', labelsize=25) 
mpl.rc('ytick', labelsize=25)
mpl.rc('axes', linewidth=1.5)
mpl.rc('legend', fontsize=14)
mpl.rc('figure', figsize=(9,8))

# %% [markdown]
# ## get data

# %%
directory = 'C:/Users/geeze/Box/biocircuits/Reed/projects/DARPA_biocon/task 4.1/20201129 cin las response 3 two step trans/'

filename = '20201129 cin las response 3 two step trans.xlsx'

# %%
dd = pd.read_excel(directory + filename, sheet_name=None)

# %%
dd.keys()
# Out:
# dict_keys(['plate1', 'plate2', 'IDs-1', 'IDs-2', 'Exp', 'plate1_tidy', 'plate2_tidy', 'all_tidy'])

# %%
sheets_to_plot = [x for x in dd.keys() if 'all' in x]

# %%
sheets_to_plot
# Out:
# ['all_tidy']

# %%
df = dd[sheets_to_plot[0]]

# %% [markdown]
# # *Time course data plots*

# %%
#get just the effects of cin (capping)

i_las0 = df['las'] == 0

# %%
sub = df.loc[i_las0]

# %%
options = df['strain'].unique()
choice = options[13]

# %%
choice
# Out:
# 'cau 8'

# %%
sub_sub = sub.loc[sub['strain'] == choice]

# %%
sns.lineplot(x='Time', y='od700', data=sub_sub, hue='cin')

# %% [markdown]
# ## now rescue

# %%
#get just the rescue effects
cin_val = 2
cin2_inds = df['cin'] == cin_val

sub = df.loc[cin2_inds]

# %%
sub_sub = sub.loc[sub['strain'] == choice]

# %%
sns.lineplot(x='Time', y='od700', data=sub_sub, hue='las')
