# %%
from glob import glob

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import datetime

# %%
def get_time (entry):
    hours, minutes, sec = entry.split(':')
    
    time = int(hours)*60*60 + int(minutes)*60 + int(sec)
    
    return time

# %% [markdown]
# ## get data, make it consistent

# %%
d ='C:/Users/geeze/Documents/media/hobbies/triathlon/tritonman results/'
match = '*.csv'

files = glob(d+match)

# %%
data = [pd.read_csv(f) for f in files]

# %%
#there are a bunch of NT spots in these, replace them with NaN

data = [d.replace('NT', np.nan) for d in data]

# %%
for d in data:
    try:
        d['finish'] = d['finish'].apply(get_time)
    except:
        pass

# %%
data = {d['yr'].unique()[0] : d for d in data}

# %%
for d in data:
    
    f = data[d]
    
    i = f['cat'] != 'Collegiate'
    
    print(d)
    sns.distplot(f.loc[i, 'finish']/60**2, hist=False, label=d)
    
plt.legend()
# Out:
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020

# %% [markdown]
# for visualization ideas
#
# https://www.coachcox.co.uk/ (ironman argentina)
#
# https://medium.com/analytics-vidhya/how-i-used-data-science-skills-to-become-triathlon-athlete-c6e17c5c652c (pairplot)
